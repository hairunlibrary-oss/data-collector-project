# %%
import pandas as pd
import kagglehub
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas as pd
# ----> 2 import kagglehub
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# Out:
#    Fase       Topik Utama                                    Materi Spesifik  \
# 0     1  Navigasi & Dasar  FHS (Struktur Folder), ls, cd, mkdir, rm, cp, mv.
# 1     2     Editor & File        Vim/Nano, cat, less, head, tail, Link (ln).
# 2     3         Hak Akses         chmod, chown, sudo, User/Group management.
# 3     4       Power Tools   I/O Redirection (>, >>), Piping (|), grep, find.
# 4     5   Text Processing       Dasar-dasar Regex, sed (stream editor), awk.
# 5     6        Bash Logic           Variabel, Parameter ($1), if-else, case.
# 6     7  Loops & Function          for loop, while loop, Reusable Functions.
# 7     8        System Ops          top/htop, crontab, systemctl, Exit Codes.
#
#                                        Target Output
# 0              Lancar berpindah direktori tanpa GUI.
# 1  Bisa mengedit file konfigurasi langsung di ter...
# 2    Memahami keamanan file dan hak eksekusi script.
# 3      Bisa mencari data di tengah ribuan baris log.
# ...

# %%
data_source = kagglehub.dataset_download("algozee/teenager-menthal-healy")

# %%
pd.read_csv("data_source")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 pd.read_csv("data_source")
#
# File ~/projects/python-automation/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...
